# %%
import matplotlib as plt
import pandas as pd
import numpy as np
import seaborn as sns
import sys
# !{sys.executable} -m pip install pandas-profiling
import pandas_profiling
from scripts import project_functions

df = project_functions.load_and_process("../data/raw/diabetes.csv")

# %%
df["Outcome"].replace({0 : "Negative", 1 : "Positive"}, inplace=True)
df.head()
# Out:
#      Pregnancies  Insulin   BMI  DiabetesPedigreeFunction  Age   Outcome
# 566            1       18  38.6                     0.412   21  Negative
# 372            0       66  35.8                     0.545   21  Negative
# 94             2       64  24.7                     0.761   21  Negative
# 486            1      480  40.7                     0.536   21  Negative
# 208            1       87  33.2                     0.289   21  Negative

# %% [markdown]
# Replaced the Values in the outcome column so interpreting in tableau would be easier to do.

# %%
df.to_csv("../data/processed/cleaned_data.csv")
